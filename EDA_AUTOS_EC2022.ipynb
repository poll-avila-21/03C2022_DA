# %% [markdown]
# <img src = "image-2.png"/>

# %% [markdown]
# <center><h1 Style = "color:#8B0000"> Análisis de datos</h1></center>
# <center><h5> UNIVERSIDAD CASTRO CARAZO</h5></center>
# <center><h6> 3C-2022</h6></center>
# </br>
# <p style = "text-align: justify"> Este notebook contiene el analisis de los datos de los vehiculos a la venta por parte de la empresa Pk2, esta empresa se encuentra interesada en responder una pregunta de negocio particular.
# Como se puede incrementar las ventas de autos de segunda mano?
# Para esto se realiza un analisis del conjunto de datos facilitado por la empresa a efectos de poder brindar conocimiento sobre las ditribuciones de sus lotes de venta, los autos con mayor precio, o caracteristicas de los autos, esto para dotar de insumos suficientes a la toma de desiciones.
# </p>
# </br>
# <a href="https://archive.ics.uci.edu/ml/datasets/Automobile"> Fuente de Datos para el proceso de analisis </a>

# %% [markdown]
# <h2 Style="color:#1E90FF">1. Carga y estandarizacion de los set de datos</h2>
#
# <p>Que se hace en esta etapa?</p>
#
# <ol>    <li>Importar las librerias de necesarias</li>    <li>Importar el o los set de datos</li>    <li>Revisar los ecabezados de los DataFrames</li>    <li>Si solo Si temenos mas de 1 set de datos - Unir los set de datos en un unico Dataframe</li>
# </ol>
#
# <h3 Style="color:#2F4F4F">1.1 Importar las librerias</h3>

# %%
import pandas as pd #se usa para el manejo de los DataFrames
import numpy as np # se usa para el manejo de estructuras de datos(arreglos, listas, tuplas y diccionarios)
import matplotlib.pyplot as plt #se usa para crear graficas.

# %% [markdown]
# <h3> Importar los Set de Datos</h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]


df_1er_autos = pd.read_csv("autos.csv" , names = cols)
df_2do_autos = pd.read_csv("Autos 1.csv" , names = cols)

# %%
df_1er_autos.head(5) #head es para ver los primeros 5 para ver los ultimos 5 usamos df_1er_autos.tail(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
df_1er_autos.tail(5) #head es para ver los primeros 5 para ver los ultimos 5 usamos df_1er_autos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# ...

# %%
df_2do_autos.head(5) #head es para ver los primeros 5 para ver los ultimos 5 usamos df_2do_autos.tail(5)
# Out:
#    symboling normalized    make fuel aspiration doors        style wheels  \
# 0          2        134  toyota  gas        std   two      hardtop    rwd
# 1          2        134  toyota  gas        std   two    hatchback    rwd
# 2          2        134  toyota  gas        std   two      hardtop    rwd
# 3          2        134  toyota  gas        std   two    hatchback    rwd
# 4          2        134  toyota  gas        std   two  convertible    rwd
#
#   engine  base  ...  engine-size  system  bore  stroke compression horsepower  \
# 0  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 1  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 2  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 3  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
# 4  front  98.4  ...          146    mpfi  3.62     3.5         9.3        116
#
#    peak City  Higway  price
# ...

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %% [markdown]
# <h5 style = "color:#00008B"> 1.3 Revisar los encabezados de los DataFrame</h5>
# <p> Se motiva la estandarización de los nombres y columnas, considerando lo siguiente</p>
# <ol>
#     <li> Los nombres de las columnas no deben de tener espacios en blanco</li>
#     <li> Los nombres no pueden comenzar numeros</li>
#     <li> Si el nombre se conforma por 2 o mas palabras la letra inicial de cada palabra va en mayuscula </li>
#     <li> No deben existir nombres repetidos</li>
# </ol>

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_autos.rename ({"egine-size": "egineSize"} , axis = 1 , inplace = True)

# %%
df_2do_autos.rename ({"egine-size": "egineSize"} , axis = 1 , inplace = True)

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# <h5 style = "color:#00008B"> Revision de variables</h5>
# <p> Este proceso de revisión permite identificarvariables o datos que deben ser analizados de manera independiente, porque no concuerdan con la mmetadata</p>

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %%
df_1er_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engine-size  197 non-null    int64
#  17  system       197 non-null    object
# ...

# %%
temp = df_1er_autos.groupby(["style"]).count () #Sirve para agrupar
temp = temp.iloc[:,:1] #sirve para entrada de una columna solo atributo o valor es un filtro
temp
# Out:
#              symboling
# style
# convertible          6
# hardtop              8
# hatchback           70
# sedan               90
# wagon               23

# %% [markdown]
# <h5 style = "color:#00008B"> 1.4 Unir set de Datos</h5>

# %%
unionArchivos = [df_1er_autos, df_2do_autos]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 style= "color: #1da2c3"> 2. Manejo de los valores faltantes o perdidos </h2>
# <p> ¿Que se hace en este apartado?</p>
# <ol>
#     <li> Identidicar como se muestran los valors faltantes y los estadarizamos (Nan)</li>
#     <li> Contar con una cantidad de valores faltantes por variable </li>
#     <li> Anáisis de imputacion de valores como numeros con la media</li>
#     <li> Anáisis de imputacion de valores categoricos con el más frecuente</li>
#     <li> Eliminar filas con valores faltantes</li>
#   </ol>
#
# <h2 style='color: #1da2c3'> 2.1 Identificar como se muestran los valores faltantes y los estandarizamos (NaN) </h2>

# %%
dfAutos.replace("?", np.nan , inplace = True )
dfAutos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2        NaN         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1        NaN         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0        NaN         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...          130    mpfi  3.47    2.68         9.0
# ...

# %% [markdown]
# <h2 style='color: #1da2c3'> 2.2 Contar la cantidad de valores faltantes por variable </h2>

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engine-size  system   bore  stroke  compression  \
# 0   False  False  ...        False   False  False   False        False
# 1   False  False  ...        False   False  False   False        False
# 2   False  False  ...        False   False  False   False        False
# 3   False  False  ...        False   False  False   False        False
# 4   False  False  ...        False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# ...

# %%
for column in dfValoresFaltantes.columns.values.tolist():
    print (column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engine-size
# False    226
# Name: engine-size, dtype: int64
#
# system
# ...

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  226.000000  226.000000  226.000000  226.000000  226.000000
# mean     0.902655   98.626991  173.929646   65.853982   53.728761
# std      1.271672    5.611570   11.744470    2.015475    2.365420
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.300000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  101.800000  180.200000   66.500000   55.600000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   226.000000   226.000000   226.000000  226.000000  226.000000
# mean   2540.597345   126.486726    10.300973   25.477876   31.044248
# std     498.165891    40.340465     4.148393    6.384143    6.767096
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# ...

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
#
# [3 rows x 26 columns]

# %%
dfAutos.tail(3)
# Out:
#     symboling normalized   make fuel aspiration doors  style wheels engine  \
# 26         -2        103  volvo  gas        std  four  sedan    rwd  front
# 27         -1         74  volvo  gas        std  four  wagon    rwd  front
# 28         -2        103  volvo  gas        std  four  sedan    rwd  front
#
#      base  ...  engine-size  system  bore  stroke compression horsepower  \
# 26  104.3  ...          141    mpfi  3.78    3.15         9.5        114
# 27  104.3  ...          141    mpfi  3.78    3.15         9.5        114
# 28  104.3  ...          141    mpfi  3.78    3.15         9.5        114
#
#     peak City Higway  price
# 26  5400   23     28  12940
# 27  5400   23     28  13415
# 28  5400   24     28  15985
#
# [3 rows x 26 columns]

# %% [markdown]
# <h2 style='color: #1da2c3'> 2.3 Contar la cantidad de valores faltantes por variable </h2>
# <img src= "datosfaltantes.png" alt = "Valores Perdidos">

# %%
mean_value = dfAutos ["normalized"].astype("float").mean(axis = 0) #Obteniendo la media de la variable
print("La media normalized es: ", mean_value)
# Out:
# La media normalized es:  122.28333333333333

# %%
dfAutos["normalized"].replace(np.nan, 122, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
mean_value = dfAutos ["bore"].astype("float").mean(axis = 0) #Obteniendo la media de la variable
print("La media bore es: ", mean_value)

dfAutos["bore"].replace(np.nan, 3.3, inplace = True)
dfAutos.head(5)
# Out:
# La media bore es:  3.319459459459461
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# ...

# %%
mean_value = dfAutos ["stroke"].astype("float").mean(axis = 0) #Obteniendo la media de la variable
print("La media stroke es: ", mean_value)
# Out:
# La media stroke es:  3.2785135135135075

# %%
dfAutos["stroke"].replace(np.nan, 3.2 , inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
mean_value = dfAutos ["horsepower"].astype("float").mean(axis = 0) #Obteniendo la media de la variable
print("La media horsepower es: ", mean_value)
# Out:
# La media horsepower es:  102.98214285714286

# %%
dfAutos["horsepower"].replace(np.nan, 102, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
mean_value = dfAutos ["peak"].astype("float").mean(axis = 0) #Obteniendo la media de la variable
print("La media peak es: ", mean_value)
# Out:
# La media peak es:  5100.892857142857

# %%
dfAutos["peak"].replace(np.nan, 5100, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 style='color: #1da2c3'> 2.4 Analisis de imputacion de valores categoricoscon el mas frecuente </h2>

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan,"Four", inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 style='color: #1da2c3'> 2.5 Eliminar filas con valores faltantes </h2>

# %%
dfAutos.dropna(subset = ["price"], axis = 0, inplace = True)
dfAutos.reset_index(drop = True , inplace = True)

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
for column in dfValoresFaltantes.columns.values.tolist():
    print (column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# Cylinders
# False    222
# Name: Cylinders, dtype: int64
#
# engine-size
# False    222
# Name: engine-size, dtype: int64
#
# system
# False    222
# ...

# %% [markdown]
# <h2 style='color: #1da2c3'> Estandarización de los datos</h2>
# <p> Que se hace en este apartado? </p>
#
#
#
# <ol>
#     <li>Se verifica el dominio de la variable y se ajusta, si es necesario</li>
#     <li>Se convierten los valores en función de su interpretación </li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1</li>
#     <li>Binning</li>
# </ol>
#
#
#
# <h3 style="color: #B22222">3.1 Verificacion del dominio de variables</h3>

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# ...

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized      object
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore            object
# stroke          object
# compression    float64
# horsepower      object
# peak            object
# City             int64
# Higway           int64
# price           object
# dtype: object

# %%
dfAutos[["normalized"]] = dfAutos[["normalized"]].astype("int")
dfAutos[["bore" , "stroke" , "peak" , "horsepower", "price"]] = dfAutos[["bore" , "stroke" , "peak" , "horsepower" , "price"]].astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling        int64
# normalized       int32
# make            object
# fuel            object
# aspiration      object
# doors           object
# style           object
# wheels          object
# engine          object
# base           float64
# length         float64
# width          float64
# heingt         float64
# curb             int64
# engineType      object
# Cylinders       object
# engine-size      int64
# system          object
# bore           float64
# stroke         float64
# compression    float64
# horsepower     float64
# peak           float64
# City             int64
# Higway           int64
# price          float64
# dtype: object

# %% [markdown]
# <h2 style='color: #B22222'> 3.2 Estandarizacion de variables</h2>

# %%
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
#
#   horsepower    peak City  Higway    price
# 0      111.0  5000.0   21      27  13495.0
# 1      111.0  5000.0   21      27  16500.0
# 2      154.0  5000.0   19      26  16500.0
#
# [3 rows x 26 columns]

# %%
dfAutos["City L/100 km"] = 235/dfAutos["City"]
dfAutos["Higway L/100 km"] = 235/dfAutos["Higway"]
dfAutos.head(3)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower    peak  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0       111.0  5000.0
# 1    rwd  front  88.6  ...  3.47    2.68          9.0       111.0  5000.0
# 2    rwd  front  94.5  ...  2.68    3.47          9.0       154.0  5000.0
#
#   City  Higway    price  City L/100 km  Higway L/100 km
# 0   21      27  13495.0      11.190476         8.703704
# 1   21      27  16500.0      11.190476         8.703704
# 2   19      26  16500.0      12.368421         9.038462
#
# [3 rows x 28 columns]

# %% [markdown]
# <h2 style='color: #B22222'> 3.3 Normalizacion de valores</h2>

# %%
dfTemp  = dfAutos[["length" , "width" , "heingt"]]
dfTemp.head(5)
# Out:
#    length  width  heingt
# 0   168.8   64.1    48.8
# 1   168.8   64.1    48.8
# 2   171.2   65.5    52.4
# 3   176.6   66.2    54.3
# 4   176.6   66.4    54.3

# %%
dfAutos["length"] = dfAutos ["length"] / dfAutos["length"].max()
dfAutos["width"] = dfAutos ["width"] / dfAutos["width"].max()
dfAutos["heingt"] = dfAutos ["heingt"] / dfAutos["heingt"].max()

# %%
dfTemp2  = dfAutos[["length" , "width" , "heingt"]]
dfTemp2.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# <h2 style='color: #B22222'> 3.4 Binning</h2>

# %%
dfTemp  = dfAutos["horsepower"]
dfTemp.head(10)
# Out:
# 0    111.0
# 1    111.0
# 2    154.0
# 3    102.0
# 4    115.0
# 5    110.0
# 6    110.0
# 7    110.0
# 8    140.0
# 9    101.0
# Name: horsepower, dtype: float64

# %%
dfAutos.dtypes
# Out:
# symboling            int64
# normalized           int32
# make                object
# fuel                object
# aspiration          object
# doors               object
# style               object
# wheels              object
# engine              object
# base               float64
# length             float64
# width              float64
# heingt             float64
# curb                 int64
# engineType          object
# Cylinders           object
# engine-size          int64
# system              object
# bore               float64
# stroke             float64
# compression        float64
# horsepower         float64
# peak               float64
# City                 int64
# Higway               int64
# price              float64
# City L/100 km      float64
# Higway L/100 km    float64
# dtype: object

# %%
bins = np.linspace(min(dfAutos["horsepower"]) , max(dfAutos ["horsepower"]) , 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupNames = ["bajo" , "medio" , "alto"]
dfAutos["horsepowerBins"] = pd.cut(dfAutos["horsepower"], bins , labels = groupNames ,  include_lowest = True)
dfAutos[["horsepower" , "horsepowerBins"]].head(5)
# Out:
#    horsepower horsepowerBins
# 0       111.0           bajo
# 1       111.0           bajo
# 2       154.0          medio
# 3       102.0           bajo
# 4       115.0           bajo

# %%
dfAutos["horsepowerBins"].value_counts()
# Out:
# bajo     174
# medio     43
# alto       5
# Name: horsepowerBins, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


plt.pyplot.hist(dfAutos["horsepower"])


plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


plt.pyplot.hist(dfAutos["horsepowerBins"])


plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_colors = ['#000000', '#4c3c35', '#636784', '#786a58']

ax.bar(fruits, counts, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()

# %%
dfAutos.head(6)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
# 5          2         122         audi  gas        std   two        sedan
#
#   wheels engine  base  ...  stroke  compression  horsepower    peak City  \
# 0    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
# 1    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
# 2    rwd  front  94.5  ...    3.47          9.0       154.0  5000.0   19
# 3    fwd  front  99.8  ...    3.40         10.0       102.0  5500.0   24
# 4    4wd  front  99.4  ...    3.40          8.0       115.0  5500.0   18
# ...

# %% [markdown]
# <h2 style='color: #1da2c3'>4. Visualización de Datos</h2>
# <p>En este apartado se van a crear diferentes visualizaciones (Gráficas), las cuales nos ayudan a realizar la interpretaion y analisis de la informacion del set
#
# Estos son tres elementos fundamentales para poder crear las visualizaciones: </p>
#
# <ol>
# <li>Preguntas de negocio a responder</li>
# <li>Pleno conocimiento del set de datos</li>
# <li>Experiencia de negocio</li>
# </ol>

# %%
#se agrupan los datos por categoria
gf1 = dfAutos.groupby(["horsepowerBins"]).count()
#se extrae el indice y la primera columna con datos
gf1 = gf1.iloc[:,0:1]
gf1
# Out:
#                 symboling
# horsepowerBins
# bajo                  174
# medio                  43
# alto                    5

# %%
avg_plazo = gf1["symboling"].astype("float").mean(axis=0)
print ("Promedio: ", avg_plazo)
# Out:
# Promedio:  74.0

# %%
fig, ax = plt.subplots()

eje_x = gf1.index.tolist()
eje_y = gf1['symboling'].tolist()
bar_labels = ['Bajo', 'Medio', 'Alto']
bar_colors = ['#e2e2e2', '#e2e2e2', '#ff4e49']

ax.bar(eje_x, eje_y,label=bar_labels, color=bar_colors) #label=bar_labels,

ax.set_ylabel('Cantidad HP')
ax.set_title('Autos agrupados segun HP')
#ax.legend(title='HP color')

plt.show()

# %%
#Se agrupan los datos por categoria
gf2 = dfAutos.groupby(['make']).count()
# se extrae el indice y la primera colmuna con datos
gf2 = gf2.iloc[:,:1]
gf2
# Out:
#                symboling
# make
# alfa-romero            3
# audi                   6
# bmw                    8
# chevrolet              3
# dodge                  9
# honda                 13
# isuzu                  2
# jaguar                 3
# mazda                 17
# mercedes-benz          8
# mercury                1
# mitsubishi            13
# nissan                18
# peugot                11
# plymouth               7
# porsche                4
# renault                2
# saab                   6
# subaru                12
# toyota                46
# volkswagen            24
# volvo                  6

# %%
fig, ax = plt.subplots()

eje_x = gf2.index.tolist()
eje_y = gf2['symboling'].tolist()
y_pos = np.arange(len(eje_x))
bar_colors = ['#e2e2e2', '#e2e2e2', '#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2',
              '#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2',
              '#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2','#e2e2e2', '#e2e2e2',
              '#e2e2e2','#ff4e49', '#e2e2e2', '#e2e2e2']

ax.barh(y_pos, eje_y, align='center', color = bar_colors)
ax.set_yticks(y_pos, labels=eje_x)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Cantidad')
ax.set_title('Autos segun Marca')

plt.show()

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  stroke  compression  horsepower    peak City  \
# 0    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
# 1    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
#
#   Higway    price City L/100 km  Higway L/100 km  horsepowerBins
# 0     27  13495.0     11.190476         8.703704            bajo
# 1     27  16500.0     11.190476         8.703704            bajo
#
# [2 rows x 29 columns]

# %%
dfTemp = dfAutos[['fuel', 'style', 'price']]

# %%
dfAutos
# Out:
#      symboling  normalized         make    fuel aspiration doors        style  \
# 0            3         122  alfa-romero     gas        std   two  convertible
# 1            3         122  alfa-romero     gas        std   two  convertible
# 2            1         122  alfa-romero     gas        std   two    hatchback
# 3            2         164         audi     gas        std  four        sedan
# 4            2         164         audi     gas        std  four        sedan
# ..         ...         ...          ...     ...        ...   ...          ...
# 217          0         122   volkswagen  diesel      turbo  four        sedan
# 218          0         122   volkswagen     gas        std  four        wagon
# 219         -2         103        volvo     gas        std  four        sedan
# 220         -1          74        volvo     gas        std  four        wagon
# 221         -2         103        volvo     gas        std  four        sedan
#
# ...

# %%
#Se agrupan los datos por categoria
gf3 = dfAutos.groupby(['style']).count()
# se extrae el indice y la primera colmuna con datos
gf3 = gf3.iloc[:,:1]
gf3
# Out:
#              symboling
# style
# convertible          8
# hardtop             10
# hatchback           75
# sedan              103
# wagon               26

# %%
names = gf3.index.tolist()
style = gf3['symboling'].tolist()

my_circle = plt.Circle((0,0) , 0.7 , color = "white")
plt.pie(style, labels = names, autopct = "%1.1f%%" , colors = ["#FFD34F" , "#0623D8" , "#8F77FD" , "#FFF1F4" , "#FFFB5E"])

p = plt.gcf()
p.gca().add_artist(my_circle)

plt.show()
